# %% [markdown]
# # 📊 Datajud e Pyspark
#
# Este notebook apresenta uma análise exploratória de dados judiciais utilizando **PySpark** em modo local, coletando registros da **API pública do CNJ (DataJud)** para os tribunais de PB, PE e RN no período de janeiro de 2024 até o momento atual.

# %% [markdown]
# ## 1. Descrição dos Dados
# A API DataJud oferece acesso a processos judiciais de todos os tribunais estaduais brasileiros. Para esta atividade, extraímos dados dos tribunais da Paraíba (PB), Pernambuco (PE) e Rio Grande do Norte (RN). Os registros incluem informações como data de ajuizamento, movimentações, assuntos, juízes, classe processual e grau.
# - **Período**: Jan/2024 até hoje
# - **Tribunais**: PB, PE, RN
# - **Formato de coleta**: Scroll API com paginação

# %%
# === 0. IMPORTS ===
import requests, time
from datetime import datetime
from pyspark.sql import SparkSession, Row
from pyspark.sql.functions import to_date, datediff, col, explode, count, avg
from pyspark.sql.types import StructType, StructField, StringType, IntegerType
import plotly.express as px



# === 1. INICIA A SPARK SESSION ===
# == pode-se mudar para 4g-6g a depender do hardware do PC ==
spark = SparkSession.builder \
    .appName("DataJud_Analise_Completo") \
    .config("spark.executor.memory","8g") \
    .config("spark.driver.memory","4g") \
    .config("spark.sql.shuffle.partitions","200") \
    .getOrCreate()


# === 2. CONFIGURAÇÕES DA API & CONSTS ===
API_KEY = "APIKey cDZHYzlZa0JadVREZDJCendQbXY6SkJlTzNjLV9TRENyQk1RdnFKZGRQdw=="
HEADERS = {"Content-Type":"application/json","Authorization":API_KEY}
PAGE_SIZE = 1000
SCROLL_TTL = "2m"
SCROLL_URL = "https://api-publica.datajud.cnj.jus.br/_search/scroll"

TRIBUNAIS = {
    'PB':'https://api-publica.datajud.cnj.jus.br/api_publica_tjpb/_search',
    'PE':'https://api-publica.datajud.cnj.jus.br/api_publica_tjpe/_search',
    'RN':'https://api-publica.datajud.cnj.jus.br/api_publica_tjrn/_search'
}

# %%
# === 3. CONFIGURAÇÃO DE PERÍODO E LIMITE ===
# Defina o intervalo de interesse para a coleta de processos (YYYY-MM-DDThh:mm:ss.000Z).
# Para evitar sobrecarga e facilitar testes, ajuste MAX_DOCS para um valor menor
# (por exemplo, 10.000 ou 100.000) – caso contrário, o script tentará baixar todos
# os processos do período, o que pode demorar muito dependendo da sua máquina.
DATA_INICIO="2024-01-01T00:00:00.000Z"
DATA_FIM = datetime.utcnow().strftime("%Y-%m-%dT%H:%M:%S.000Z")
MAX_DOCS=10000000  # altere para None (ilimitado) ou outro valor conforme necessidade

# %%
# === 4. FUNÇÃO DE “FLATTEN”: TRANSFORMA HITS EM REGISTROS SIMPLES ===

def flatten_hit(hit, estado):
    src = hit.get("_source",{})
    dt_aju = src.get("dataAjuizamento")
    dt_upd = src.get("dataHoraUltimaAtualizacao")
    # contagens
    movs = src.get("movimentos") or []
    movs = movs if isinstance(movs,list) else []
    ass = src.get("assuntos") or []
    ass = ass if isinstance(ass,list) else []
    # juiz
    juiz = None
    og = src.get("orgaoJulgador")
    if isinstance(og,dict): juiz = og.get("nome")
    # classe
    classe = src.get("classe",{}).get("nome")
    # grau
    grau = src.get("grau")
    # assunto principal
    ap = None
    if ass and isinstance(ass[0],dict): ap=ass[0].get("nome")
    return Row(
        estado=estado,
        dataAjuizamento=dt_aju,
        dataAtualizacao=dt_upd,
        movimentos_count=len(movs),
        assuntos_count=len(ass),
        classe=classe,
        grau=grau,
        juiz=juiz,
        assunto_principal=ap
    )

# %%
# === 5. EXTRAI APELAÇÕES em (estado,hora) ===
def extract_apel(hit, estado):
    src = hit.get("_source",{})
    movs = src.get("movimentos") or []
    movs = movs if isinstance(movs,list) else []
    rows=[]
    for m in movs:
        nome = (m.get("nome") or "").lower()
        if "apela" in nome:
            dt = m.get("dataHora")
            if dt and len(dt)>=13:
                hora = int(dt[11:13])
                rows.append(Row(estado=estado, hora=hora))
    return rows

# %% [markdown]
#  ## 2. Coleta processos e registros de apelações de um tribunal via API DataJud,
# Parâmetros:
#     - sigla (str): sigla do tribunal (por exemplo, 'PB').
#     - url (str): endpoint da API para o tribunal.
#
# Funcionamento:
# - Envia a requisição inicial com filtro de data (DATA_INICIO a DATA_FIM)
#   e tamanho de página (PAGE_SIZE).
# - Extrai o scroll_id retornado pela API para continuar na próxima página.
# Em cada iteração:
# - Converte cada hit em Row via flatten_hit.
# - Extrai registros de apelações com extract_apel.
# - Para se atingir MAX_DOCS ou quando não houver mais hits.
# - Realiza nova requisição de scroll até esgotar os resultados.
#
# Retorna:
# - prots: lista de Row com processos normalizados.
# - apeos: lista de Row com horas de apelações extraídas.

# %%
# === 6. PAGINAÇÃO + COLETA ===
def collect_for(sigla,url):
    prots=[]    # para processos
    apeos=[]    # para apelações
    payload={"size":PAGE_SIZE,"query":{"range":{"dataAjuizamento":{"gte":DATA_INICIO,"lte":DATA_FIM}}}}
    r=requests.post(f"{url}?scroll={SCROLL_TTL}",headers=HEADERS,json=payload)
    r.raise_for_status()
    data=r.json()
    scroll_id=data.get("_scroll_id")
    hits=data.get("hits",{}).get("hits",[])
    while hits and (MAX_DOCS is None or len(prots)<MAX_DOCS):
        for h in hits:
            prots.append(flatten_hit(h,sigla))
            apeos.extend(extract_apel(h,sigla))
            if MAX_DOCS and len(prots)>=MAX_DOCS: break
        if not hits or (MAX_DOCS and len(prots)>=MAX_DOCS): break
        r=requests.post(SCROLL_URL,headers=HEADERS,json={"scroll":SCROLL_TTL,"scroll_id":scroll_id})
        r.raise_for_status()
        data=r.json()
        scroll_id=data.get("_scroll_id")
        hits=data.get("hits",{}).get("hits",[])
    return prots,apeos

# %%
# === 7. COLETA DOS DADOS  -  PODE DEMORAR 5, 10, 20 MINUTOS A DEPENDER DO SEU PC ===
all_prots=[]
all_ape=[]
for sig,url in TRIBUNAIS.items():
    print("Buscando",sig)
    p,a = collect_for(sig,url)
    all_prots.extend(p)
    all_ape.extend(a)
    time.sleep(0.2)
# Out:
# Buscando PB
# Buscando PE
# Buscando RN

# %%
print(f"Total de processos lidos: {len(all_prots)}")
# Out:
# Total de processos lidos: 3000

# %%
# === 8. CRIA RDDs + DF SPARK ===
rdd_pro = spark.sparkContext.parallelize(all_prots)
df_pro = spark.createDataFrame(rdd_pro) \
    .withColumn("dt_aju", to_date("dataAjuizamento")) \
    .withColumn("dt_upd", to_date("dataAtualizacao")) \
    .withColumn("duracao_dias", datediff("dt_upd","dt_aju"))

# Definição de schema para as apelações
schema_ape = StructType([
    StructField("estado", StringType(), True),
    StructField("hora", IntegerType(), True)
])

if all_ape:
    rdd_ape = spark.sparkContext.parallelize(all_ape)
    df_ape = spark.createDataFrame(rdd_ape)
else:
    # cria DataFrame vazio com schema
    df_ape = spark.createDataFrame([], schema_ape)

df_pro.cache()
df_ape.cache()
# Out:
# DataFrame[estado: string, hora: int]

# %% [markdown]
# 9. Visualizações com Pandas e Plotly
# Nesta seção, transformamos os resultados do Spark em DataFrames Pandas e criamos gráficos interativos para explorar diferentes aspectos dos processos:

# %%
# === 9. VISUALIZAÇÕES PANDAS/Plotly ===

# Converte o DataFrame Spark principal para Pandas
pdf_pro = df_pro.toPandas()

# 9.1 EFICIÊNCIA DOS JUÍZES
df_eff = df_pro.groupBy("estado", "juiz") \
    .agg(
        avg("duracao_dias").alias("dur_media"),
        count("*").alias("n_proc")
    ) \
    .filter(col("n_proc") >= 20) \
    .orderBy("estado", "dur_media")

pdf_eff = df_eff.toPandas()
fig1 = px.bar(
    pdf_eff,
    x="dur_media",
    y="juiz",
    color="estado",
    orientation="h",
    title="Juízes com ≥20 processos: duração média"
)
fig1.show()


# 9.2 TOP ASSUNTOS POR ESTADO
df_ass_est = df_pro.groupBy("estado", "assunto_principal") \
    .count() \
    .orderBy("estado", col("count").desc())

pdf_ass_est = df_ass_est.toPandas()
fig2 = px.bar(
    pdf_ass_est,
    x="count",
    y="assunto_principal",
    color="assunto_principal",
    facet_col="estado",
    facet_col_wrap=3,
    category_orders={
        "estado": sorted(df_pro.select("estado").distinct().rdd.flatMap(lambda x: x).collect())
    },
    title="Top Assuntos por Estado",
    height=400
)
fig2.update_layout(showlegend=False)
fig2.show()


# 9.3 CLASSES PROCESSUAIS POR ESTADO (TOP >50)
df_cls_est = df_pro.groupBy("estado", "classe") \
    .count() \
    .filter(col("count") > 50) \
    .orderBy("estado", col("count").desc())

pdf_cls_est = df_cls_est.toPandas()
fig3 = px.bar(
    pdf_cls_est,
    x="count",
    y="classe",
    color="estado",
    facet_col="estado",
    facet_col_wrap=3,
    title="Classes Processuais (>50 processos) por Estado",
    height=800
)
fig3.update_layout(showlegend=False)
fig3.show()


# 9.4 HISTOGRAMA DA DURAÇÃO DOS PROCESSOS POR ESTADO
fig4 = px.histogram(
    pdf_pro,
    x="duracao_dias",
    facet_col="estado",
    facet_col_wrap=3,
    nbins=50,
    title="Distribuição da Duração dos Processos (dias) por Estado",
    labels={"duracao_dias": "Duração (dias)", "count": "Número de Processos"}
)
fig4.update_layout(
    height=1000,
    showlegend=False
)
# Desacopla eixos X para cada faceta
fig4.for_each_xaxis(lambda ax: ax.update(matches=None))
fig4.show()


# 9.5 QUANTIDADE DE PROCESSOS POR GRAU E ESTADO
df_grau_est = df_pro.groupBy("estado", "grau") \
    .count() \
    .orderBy("estado", col("count").desc())

pdf_grau_est = df_grau_est.toPandas()
fig5 = px.bar(
    pdf_grau_est,
    x="grau",
    y="count",
    color="estado",
    barmode="group",
    title="Quantidade de Processos por Grau e Estado"
)
fig5.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="29de2957-dde5-43bd-8dfe-26bece78b95c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("29de2957-dde5-43bd-8dfe-26bece78b95c")) {                    Plotly.newPlot(                        "29de2957-dde5-43bd-8dfe-26bece78b95c",                        [{"alignmentgroup":"True","hovertemplate":"estado=PB\u003cbr\u003edur_media=%{x}\u003cbr\u003ejuiz=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PB","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"PB","offsetgroup":"PB","orientation":"h","showlegend":true,"textposition":"auto","x":[58.80952380952381,119.95918367346938,123.675,127.08474576271186,136.375,145.25531914893617,149.67924528301887,149.7941176470588,152.63888888888889,157.59375,160.08333333333334,177.79268292682926,187.8923076923077,201.18333333333334,202.7887323943662,204.078125,207.24242424242425,264.2835820895522],"xaxis":"x","y":["Gabinete 08 - Des. Frederico Martinho da Nóbrega Coutinho","Gabinete 17 - Desa. Agamenilde Dias Arruda Vieira Dantas","Gabinete 10 - Des. João Benedito da Silva","Gabinete 06 - Des. Joás de Brito Pereira Filho","Gabinete 03 - Des. Márcio Murilo da Cunha Ramos","Gabinete 18 - Des. João Batista Barbosa","Gabinete 01 - Desa. Lilian Frassinetti Correia Cananéa","Gabinete 16 - Des. Ricardo Vital de Almeida","Gabinete 02 - Desa. Maria de Fátima Moraes Bezerra Cavalcanti Maranhão","Gabinete 04 - Des. Saulo Henriques de Sá e Benevides","Gabinete 05 - Des. Marcos Cavalcanti de Albuquerque","Gabinete 14 - Des. Leandro dos Santos","Gabinete 11 - Des. José Ricardo Porto","Gabinete 13 - Desembargador (Vago)","Gabinete 15 - Des. Oswaldo Trigueiro do Valle Filho","Gabinete 19 - Des. Aluizio Bezerra Filho","Gabinete 09 - Des. Abraham Lincoln da Cunha Ramos","Gabinete 07 - Des. Horácio Ferreira de Melo Júnior"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"estado=RN\u003cbr\u003edur_media=%{x}\u003cbr\u003ejuiz=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"RN","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"RN","offsetgroup":"RN","orientation":"h","showlegend":true,"textposition":"auto","x":[84.0,87.39473684210526,93.4,113.87671232876713,114.82608695652173,117.125,121.85714285714286,128.36363636363637,131.43076923076924,134.2,142.28125,143.8235294117647,148.66666666666666,157.37735849056602,213.35416666666666,340.5135135135135],"xaxis":"x","y":["3ª TURMA RECURSAL","2ª TURMA RECURSAL","3º JUIZADO ESPECIAL DA FAZENDA PÚBLICA","JUIZADO ESPECIAL CÍVEL, CRIMINAL E DA FAZENDA PÚBLICA","1º JUIZADO ESPECIAL DA FAZENDA PÚBLICA","4º JUIZADO ESPECIAL CÍVEL, CRIMINAL E DA FAZENDA PÚBLICA","3ª VARA","2º JUIZADO ESPECIAL DA FAZENDA PÚBLICA","VARA ÚNICA","4º JUIZADO ESPECIAL DA FAZENDA PÚBLICA","5º JUIZADO ESPECIAL DA FAZENDA PÚBLICA","1ª VARA","6º JUIZADO ESPECIAL DA FAZENDA PÚBLICA","2ª VARA","1ª TURMA RECURSAL","NÚCLEO DE EXECUÇÕES FISCAIS ESTADUAIS 4.0"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4d117b0e-8505-49ee-861d-7562ddfc192c" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4d117b0e-8505-49ee-861d-7562ddfc192c")) {                    Plotly.newPlot(                        "4d117b0e-8505-49ee-861d-7562ddfc192c",                        [{"alignmentgroup":"True","hovertemplate":"assunto_principal=%{y}\u003cbr\u003eestado=PB\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bancários","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Bancários","offsetgroup":"Bancários","orientation":"h","showlegend":true,"textposition":"auto","x":[88],"xaxis":"x","y":["Bancários"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"assunto_principal=%{y}\u003cbr\u003eestado=RN\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bancários","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Bancários","offsetgroup":"Bancários","orientation":"h","showlegend":false,"textposition":"auto","x":[7],"xaxis":"x3","y":["Bancários"],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"assunto_principal=%{y}\u003cbr\u003eestado=PB\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Seguro","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Seguro","offsetgroup":"Seguro","orientation":"h","showlegend":true,"textposition":"auto","x":[42],"xaxis":"x","y":["Seguro"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"assunto_principal=%{y}\u003cbr\u003eestado=PE\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Seguro","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Seguro","offsetgroup":"Seguro","orientation":"h","showlegend":false,"textposition":"auto","x":[9],"xaxis":"x2","y":["Seguro"],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"assunto_principal=%{y}\u003cbr\u003eestado=RN\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Seguro","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Seguro","offsetgroup":"Seguro","orientation":"h","showlegend":false,"textposition":"auto","x":[5],"xaxis":"x3","y":["Seguro"],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"assunto_principal=%{y}\u003cbr\u003eestado=PB\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Indenização por Dano Moral","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Indenização por Dano Moral","offsetgroup":"Indenização por Dano Moral","orientation":"h","showlegend":true,"textposition":"auto","x":[42],"xaxis":"x","y":["Indenização por Dano Moral"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"assunto_principal=%{y}\u003cbr\u003eestado=PE\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Indenização por Dano Moral","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Indenização por Dano Moral","offsetgroup":"Indenização por Dano Moral","orientation":"h","showlegend":false,"textposition":"auto","x":[5],"xaxis":"x2","y":["Indenização por Dano Moral"],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"assunto_principal=%{y}\u003cbr\u003eestado=RN\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Indenização por Dano Moral","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Indenização por Dano Moral","offsetgroup":"Indenização por Dano Moral","orientation":"h","showlegend":false,"textposition":"auto","x":[79],"xaxis":"x3","y":["Indenização por Dano Moral"],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"assunto_principal=%{y}\ ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="103b5823-b12e-4ca6-9b61-d76f470126e9" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("103b5823-b12e-4ca6-9b61-d76f470126e9")) {                    Plotly.newPlot(                        "103b5823-b12e-4ca6-9b61-d76f470126e9",                        [{"alignmentgroup":"True","hovertemplate":"estado=PB\u003cbr\u003ecount=%{x}\u003cbr\u003eclasse=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PB","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"PB","offsetgroup":"PB","orientation":"h","showlegend":true,"textposition":"auto","x":[537,204,96,87],"xaxis":"x","y":["Apelação Cível","Agravo de Instrumento","Habeas Corpus Criminal","Apelação Criminal"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"estado=PE\u003cbr\u003ecount=%{x}\u003cbr\u003eclasse=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PE","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"PE","offsetgroup":"PE","orientation":"h","showlegend":true,"textposition":"auto","x":[245,131,91,70,69],"xaxis":"x2","y":["Procedimento Comum Cível","Procedimento do Juizado Especial Cível","Apelação Cível","Execução de Título Extrajudicial","Termo Circunstanciado"],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"estado=RN\u003cbr\u003ecount=%{x}\u003cbr\u003eclasse=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"RN","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"RN","offsetgroup":"RN","orientation":"h","showlegend":true,"textposition":"auto","x":[202,181,131,111,61,57],"xaxis":"x3","y":["Procedimento do Juizado Especial da Fazenda Pública","Procedimento Comum Cível","Procedimento do Juizado Especial Cível","Recurso Inominado Cível","Execução Fiscal","Execução de Título Extrajudicial"],"yaxis":"y3","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333, ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="12b18823-086d-4a0c-87b9-fd2d673b755e" class="plotly-graph-div" style="height:1000px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("12b18823-086d-4a0c-87b9-fd2d673b755e")) {                    Plotly.newPlot(                        "12b18823-086d-4a0c-87b9-fd2d673b755e",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"estado=PB\u003cbr\u003eDuração (dias)=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":50,"offsetgroup":"","orientation":"v","showlegend":false,"x":[469,464,464,464,464,464,331,119,331,119,331,331,331,119,331,119,330,119,119,331,331,331,331,119,331,119,119,119,119,119,330,119,119,330,118,330,118,118,330,330,330,330,330,330,330,118,330,118,118,330,118,118,330,118,118,329,118,329,118,118,329,118,329,118,329,118,329,118,118,118,118,118,118,329,118,329,329,118,118,328,118,118,328,118,328,118,118,118,118,118,118,118,118,118,118,118,328,118,327,116,327,327,327,117,117,117,327,327,117,327,117,117,117,324,324,324,324,324,324,324,324,115,115,323,323,323,336,336,332,115,331,324,324,114,324,113,326,114,113,328,327,113,329,113,330,336,112,341,342,111,110,110,345,110,110,110,352,110,357,356,358,359,362,107,362,363,106,106,106,105,104,103,102,101,101,100,100,100,99,99,99,99,99,99,99,99,99,99,98,98,98,98,98,98,98,98,98,98,98,98,98,98,98,98,98,98,97,97,97,97,97,96,96,96,96,96,94,94,93,94,93,93,93,93,93,93,93,93,93,93,93,92,92,92,92,92,92,92,92,92,91,92,92,92,92,92,92,92,91,91,91,91,91,91,91,91,91,91,91,91,91,91,91,91,91,90,90,90,90,90,90,90,90,90,90,90,90,90,90,90,89,89,89,89,89,89,89,89,89,89,89,89,89,89,89,119,119,119,119,119,119,119,119,119,119,119,119,119,118,118,118,118,118,111,109,105,103,103,99,99,99,99,98,98,98,98,98,123,119,96,93,90,90,90,123,121,121,121,121,120,98,98,97,97,96,96,96,93,93,93,92,92,92,91,90,90,90,89,89,89,99,99,97,96,92,91,90,90,468,464,464,364,40,364,40,364,175,175,364,175,364,175,40,40,175,175,40,363,175,40,363,40,363,175,363,175,175,363,175,64,40,175,64,175,174,174,174,174,64,174,174,64,363,174,40,363,40,64,40,40,174,64,174,64,40,40,363,40,64,40,363,64,40,363,362,362,64,362,64,40,64,40,362,64,362,64,362,40,64,362,64,362,362,40,174,362,64,40,174,361,361,174,361,40,64,40,174,64,40,174,64,64,40,360,174,359,174,40,64,40,64,359,64,64,174,64,359,174,359,174,174,64,174,174,38,359,38,359,64,173,173,64,38,64,173,359,64,173,359,64,359,359,359,64,359,64,37,64,64,359,64,64,64,173,359,64,37,173,64,359,64,359,64,359,37,173,64,359,37,173,37,64,37,37,173,359,37,173,37,64,173,64,37,173,173,64,173,37,173,173,173,358,173,37,173,37,173,37,37,173,173,64,37,37,173,64,64,37,63,173,64,64,37,173,173,173,37,63,172,63,37,63,37,37,63,63,37,63,63,172,63,37,37,63,63,358,63,37,358,37,37,171,63,37,63,358,37,357,37,37,37,170,37,63,63,37,37,357,357,37,63,37,63,357,37,37,357,357,37,63,357,37,357,37,357,37,356,63,36,36,356,63,63,356,63,356,63,36,170,63,63,356,170,63,356,63,63,170,63,170,63,63,63,170,356,63,170,71,170,71,170,71,170,355,71,170,170,355,170,70,170,355,170,69,355,355,70,169,69,355,169,169,169,169,169,169,169,169,355,355,354,352,169,69,352,169,352,69,69,352,169,352,68,169,352,352,169,64,352,169,71,352,71,169,352,352,71,70,169,70,70,169,69,69,69,69,169,169,169,69,69,169,69,69,169,69,69,169,68,169,68,68,169,169,168,68,68,67,67,352,67,352,352,65,352,65,65,351,351,65,351,65,351,65,351,168,64,168,351,168,64,64,351,168,64,168,168,351,168,351,64,168,351,64,64,351,351,64,168,168,64,351,64,168,168,350,168,349,349,349,349,168,168,168,168,168,349,168,168,168,349,349,168,348,348,348,348,168,348,168,168,348,348,348,167,348,167,348,167,348,167,348,167,167,167,167,167,348,348,167,348,167,167,348,348,348,167,348,348,167,347,167,167,167,89 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ef754fae-045a-4a38-9256-e79c083f7db7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ef754fae-045a-4a38-9256-e79c083f7db7")) {                    Plotly.newPlot(                        "ef754fae-045a-4a38-9256-e79c083f7db7",                        [{"alignmentgroup":"True","hovertemplate":"estado=PB\u003cbr\u003egrau=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PB","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"PB","offsetgroup":"PB","orientation":"v","showlegend":true,"textposition":"auto","x":["G2"],"xaxis":"x","y":[1000],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"estado=PE\u003cbr\u003egrau=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PE","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"PE","offsetgroup":"PE","orientation":"v","showlegend":true,"textposition":"auto","x":["G1","JE","G2"],"xaxis":"x","y":[626,231,143],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"estado=RN\u003cbr\u003egrau=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"RN","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"RN","offsetgroup":"RN","orientation":"v","showlegend":true,"textposition":"auto","x":["G1","JE","TR"],"xaxis":"x","y":[462,423,115],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556," ...

# %%
# === 10. TABELAS RESUMO ===

# === 10.1.  CONTAGEM DE PROCESSOS POR ESTADO  POR ASSUNTO  ===

df_pro.groupBy("estado", "assunto_principal") \
    .count() \
    .orderBy("estado", col("count").desc()) \
    .show(100, truncate=False)

# === 10.2.  MÉDIA DE DIAS POR PROCESSO  ===
df_pro.groupBy("estado") \
    .agg({"duracao_dias": "avg"}) \
    .withColumnRenamed("avg(duracao_dias)", "duracao_media_dias") \
    .orderBy("estado") \
    .show()

# === 10.3. CONTAGEM DE PROCESSOS POR GRAU POR ESTADO  ===
df_pro.groupBy("grau") \
    .count() \
    .orderBy(col("count").desc()) \
    .show()
# Out:
# +------+--------------------------------------------------------------------------------------------+-----+
# |estado|assunto_principal                                                                           |count|
# +------+--------------------------------------------------------------------------------------------+-----+
# |PB    |Bancários                                                                                   |88   |
# |PB    |Seguro                                                                                      |42   |
# |PB    |Indenização por Dano Moral                                                                  |42   |
# |PB    |Tarifas                                                                                     |40   |
# |PB    |Municipais                                                                                  |39   |
# |PB    |Empréstimo consignado                                                                       |37   |
# |PB    |Habeas Corpus - Cabimento                                                                   |22   |
# |PB    |Indenização por Dano Material                                                               |19   |
# |PB    |Liminar                                                                                     |19   |
# |PB    |ICMS/ Imposto sobre Circulação de Mercadorias                                               |18   |
# |PB    |Obrigação de Fazer / Não Fazer                                                              |16   |
# |PB    |Contratos Bancários                                                                         |16   |
# |PB    |Cartão de Crédito                                                                           |15   |
# |PB    |Competência                                                                                 |14   |
# |PB    |Prisão Preventiva                                                                           |12   |
# |PB    |Tráfico de Drogas e Condutas Afins                                                          |11   |
# |PB    |Planos de saúde                                                                             |11   |
# |PB    |Assistência Judiciária Gratuita                                                             |10   |
# |PB    |Pena Privativa de Liberdade                                                                 |10   |
# |PB    |Homicídio Qualificado                                                                       |10   |
# |PB    |Roubo Majorado                                                                              |10   |
# |PB    |Roubo                                                                                       |10   |
# |PB    |Fornecimento de medicamentos                                                                |9    |
# |PB    |Associação para a Produção e Tráfico e Condutas Afins                                       |9    |
# |PB    |Capitalização e Previdência Privada                                                         |9    |
# |PB    |Excesso de prazo para instrução / julgamento                                                |9    |
# |PB    |Efeito Suspensivo / Impugnação / Embargos à Execução                                        |8    |
# |PB    |Alienação Fiduciária                                                                        |8    |
# |PB    |Tratamento médico-hospitalar                                                                |8    |
# |PB    |Crimes do Sistema Nacional de Armas                                                         |7    |
# |PB    |Crimes de Trânsito                                                                          |7    |
# |PB    |Inclusão Indevida em Cadastro de Inadimplentes                                              |7    |
# |PB    |Multas e demais Sanções                                                                     |6    |
# |PB    |Acidente de Trânsito                                                                        |6    |
# |PB    |Abono Pecuniário (Art. 78 Lei 8.112/1990)                                                   |6    |
# |PB    |Receptação                                                                                  |6    |
# |PB    |FGTS/Fundo de Garantia por Tempo de Serviço                                                 |6    |
# |PB    |Abuso de Poder                                                                              |6    |
# |PB    |Atualização de Conta                                                                        |6    |
# |PB    |Correção Monetária                                                                          |6    |
# |PB    |Fornecimento de Energia Elétrica                                                            |5    |
# |PB    |Práticas Abusivas                                                                           |5    |
# |PB    |ITBI - Imposto de Transmissão Intervivos de Bens Móveis e Imóveis                           |5    |
# |PB    |Furto Qualificado                                                                           |5    |
# |PB    |Adimplemento e Extinção                                                                     |5    |
# |PB    |Crimes contra a Ordem Tributária                                                            |4    |
# |PB    |Crimes de Tráfico Ilícito e Uso Indevido de Drogas                                          |4    |
# |PB    |Anulação e Correção de Provas / Questões                                                    |4    |
# |PB    |Aplicação da Pena                                                                           |4    |
# |PB    |Ameaça                                                                                      |4    |
# |PB    |Piso Salarial                                                                               |4    |
# |PB    |ICMS / Incidência Sobre o Ativo Fixo                                                        |4    |
# |PB    |Cédula de Crédito Bancário                                                                  |4    |
# |PB    |Interpretação / Revisão de Contrato                                                         |4    |
# |PB    |Causas Supervenientes à Sentença                                                            |4    |
# |PB    |Homicídio Simples                                                                           |4    |
# |PB    |Agência e Distribuição                                                                      |4    |
# |PB    |Custas                                                                                      |3    |
# |PB    |Alimentos                                                                                   |3    |
# |PB    |Liberdade Provisória                                                                        |3    |
# |PB    |Auxílio-Doença Acidentário                                                                  |3    |
# |PB    |Decorrente de Violência Doméstica                                                           |3    |
# |PB    |Rescisão do contrato e devolução do dinheiro                                                |3    |
# |PB    |Ato / Negócio Jurídico                                                                      |3    |
# |PB    |Adicional por Tempo de Serviço                                                              |3    |
# |PB    |Cumprimento Provisório de Sentença                                                          |3    |
# |PB    |Contra a Mulher                                                                             |3    |
# |PB    |IPVA - Imposto Sobre Propriedade de Veículos Automotores                                    |3    |
# |PB    |Estabelecimentos de Ensino                                                                  |3    |
# |PB    |Furto                                                                                       |3    |
# |PB    |Abatimento proporcional do preço                                                            |3    |
# |PB    |Honorários Advocatícios                                                                     |3    |
# |PB    |Classificação e/ou Preterição                                                               |3    |
# |PB    |Tutela de Urgência                                                                          |3    |
# |PB    |IPTU/ Imposto Predial e Territorial Urbano                                                  |3    |
# |PB    |Suspeição                                                                                   |3    |
# |PB    |Homicidio qualificado                                                                       |3    |
# |PB    |Expurgos Inflacionários / Planos Econômicos                                                 |3    |
# |PB    |Ausência de Cobrança Administrativa Prévia                                                  |3    |
# |PB    |ISS/ Imposto sobre Serviços                                                                 |3    |
# |PB    |Plano de Saúde                                                                              |2    |
# |PB    |Responsabilidade Tributária do Sócio-Gerente / Diretor / Representante                      |2    |
# |PB    |Esbulho / Turbação / Ameaça                                                                 |2    |
# |PB    |Depoimento                                                                                  |2    |
# |PB    |Incapacidade Laborativa Permanente                                                          |2    |
# |PB    |Nomeação                                                                                    |2    |
# |PB    |Locação de Imóvel                                                                           |2    |
# |PB    |Estaduais                                                                                   |2    |
# |PB    |Adulteração de Sinal Identificador de Veículo Automotor                                     |2    |
# |PB    |Livramento condicional                                                                      |2    |
# |PB    |Indenização do Prejuízo                                                                     |2    |
# |PB    |PIS/PASEP                                                                                   |2    |
# |PB    |Oncológico                                                                                  |2    |
# |PB    |Colaboração com Grupo, Organização ou Associação Destinados à Produção ou Tráfico de Drogas |2    |
# |PB    |Peculato                                                                                    |2    |
# |PB    |Reconhecimento / Dissolução                                                                 |2    |
# |PB    |Anulação                                                                                    |2    |
# |PB    |Fornecimento de insumos                                                                     |2    |
# |PB    |Abono de Permanência                                                                        |2    |
# |PB    |Feminicídio                                                                                 |2    |
# +------+--------------------------------------------------------------------------------------------+-----+
# only showing top 100 rows
#
# +------+------------------+
# |estado|duracao_media_dias|
# +------+------------------+
# |    PB|           170.487|
# |    PE|            191.66|
# |    RN|           141.883|
# +------+------------------+
#
# +----+-----+
# |grau|count|
# +----+-----+
# |  G2| 1143|
# |  G1| 1088|
# |  JE|  654|
# |  TR|  115|
# +----+-----+

# %%
# === 11. ENCERRANDO SESSÃO  ===
spark.stop()
